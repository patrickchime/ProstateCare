# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Keras
from keras import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from keras.layers import Dropout
from keras.optimizers import Adam

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from tensorflow.keras.utils import to_categorical

# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Read dataset
file_path = "/content/drive/MyDrive/Mr. Dams/Predicting Prostate Cancer/prostate-cancer-data.csv"

df = pd.read_csv(file_path)

# Print top rows
df.head()
# Out:
#      lcavol   lweight  age      lbph       lcp  gleason  pgg45      lpsa  \
# 0 -0.579818  2.769459   50 -1.386294 -1.386294        6      0 -0.430783
# 1 -0.994252  3.319626   58 -1.386294 -1.386294        6      0 -0.162519
# 2 -0.510826  2.691243   74 -1.386294 -1.386294        7     20 -0.162519
# 3 -1.203973  3.282789   58 -1.386294 -1.386294        6      0 -0.162519
# 4  0.751416  3.432373   62 -1.386294 -1.386294        6      0  0.371564
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# ## Split data

# %%
# Convert Target variable to categorical
df['Target'] = to_categorical(df['Target'])

# Split dataset
x_train, x_test, y_train, y_test = train_test_split(df.drop('Target', axis=1), df['Target'], test_size=0.2, random_state=42)

# validation data
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# shape
print(f"x_train shape: {x_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"x_val shape: {x_val.shape}")
# Out:
# x_train shape: (61, 8)
# x_test shape: (20, 8)
# x_val shape: (16, 8)

# %%
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
print(f"y_val shape: {y_val.shape}")
# Out:
# y_train shape: (61,)
# y_test shape: (20,)
# y_val shape: (16,)

# %% [markdown]
# ## Standardization

# %%
# Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

# %% [markdown]
# # Modeling - Part 1
# ## Feedfoerward Neural Network (FNN) Model

# %%
# Instantiate a sequential model
model = Sequential()

# Add dense layers
model.add(Dense(128, input_shape=(x_train.shape[1],), activation='relu'))
model.add(Dense(64, activation='relu'))
# Dropout
model.add(Dropout(0.5))

model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(32, activation='relu'))
# Dropout
model.add(Dropout(0.5))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# Summary
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_24 (Dense)                     │ (None, 128)                 │           1,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_25 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_13 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_26 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_14 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_27 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_15 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_28 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 15,681 (61.25 KB)
#  Trainable params: 15,681 (61.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the model
import time
start = time.time()
history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
                    epochs=100, batch_size=32, callbacks=[early_stopping, model_checkpoint],
                    verbose=1)
end = time.time()
print(f"Training time: {end - start} seconds")
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 440ms/step - accuracy: 0.2259 - loss: 0.9666 - val_accuracy: 0.3125 - val_loss: 0.7342
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.2696 - loss: 0.9268 - val_accuracy: 0.3125 - val_loss: 0.7175
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.3342 - loss: 0.7603 - val_accuracy: 0.3125 - val_loss: 0.7065
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.2905 - loss: 0.7560 - val_accuracy: 0.3750 - val_loss: 0.6981
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.3337 - loss: 0.7452 - val_accuracy: 0.5000 - val_loss: 0.6909
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4628 - loss: 0.7047 - val_accuracy: 0.5625 - val_loss: 0.6854
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.4841 - loss: 0.7140 - val_accuracy: 0.6875 - val_loss: 0.6805
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.6142 - loss: 0.6849 - val_accuracy: 0.8125 - val_loss: 0.6773
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6455 - loss: 0.6650 - val_accuracy: 0.8125 - val_loss: 0.6735
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.6445 - loss: 0.6580 - val_accuracy: 0.7500 - val_loss: 0.6708
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.5705 - loss: 0.6554 - val_accuracy: 0.7500 - val_loss: 0.6681
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.6986 - loss: 0.6468 - val_accuracy: 0.7500 - val_loss: 0.6648
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6673 - loss: 0.6814 - val_accuracy: 0.7500 - val_loss: 0.6621
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8282 - loss: 0.6054 - val_accuracy: 0.7500 - val_loss: 0.6579
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.7954 - loss: 0.5916 - val_accuracy: 0.7500 - val_loss: 0.6531
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7746 - loss: 0.6498 - val_accuracy: 0.6875 - val_loss: 0.6470
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.7850 - loss: 0.5890 - val_accuracy: 0.6875 - val_loss: 0.6412
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8709 - loss: 0.5604 - val_accuracy: 0.6875 - val_loss: 0.6353
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.
uracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# Evaluate model
loss, accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9000 - loss: 0.3283
# Test Loss: 0.3283
# Test Accuracy: 0.9000

# %%
# Time to predict x_test
start = time.time()
y_pred = model.predict(x_test)
end = time.time()
print(f"Prediction time: {end - start} seconds")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# Prediction time: 0.2299973964691162 seconds

# %% [markdown]
# # Modeling - Part 2
# ## Recurrent Neural Network (RNN) Model

# %%
# prompt: build a recurrent neural network to predict Target variable


from keras.layers import LSTM, SimpleRNN, GRU

# Split dataset
x_train, x_test, y_train, y_test = train_test_split(df.drop('Target', axis=1), df['Target'], test_size=0.2, random_state=42)

# validation data
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# shape
print(f"x_train shape: {x_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"x_val shape: {x_val.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
print(f"y_val shape: {y_val.shape}")

# Standardize the features
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_val = scaler.transform(x_val)

# Reshape data for RNN
x_train = np.reshape(x_train, (x_train.shape[0], 1, x_train.shape[1]))
x_test = np.reshape(x_test, (x_test.shape[0], 1, x_test.shape[1]))
x_val = np.reshape(x_val, (x_val.shape[0], 1, x_val.shape[1]))
# Out:
# x_train shape: (61, 8)
# x_test shape: (20, 8)
# x_val shape: (16, 8)
# y_train shape: (61,)
# y_test shape: (20,)
# y_val shape: (16,)

# %%
# ## Model
# Instantiate a sequential model
model = Sequential()

# Add LSTM layer
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], x_train.shape[2])))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(1, activation='sigmoid'))

# Summary
model.summary()
# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
model_checkpoint = ModelCheckpoint('best_model.keras', monitor='val_loss', save_best_only=True)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 1, 50)               │          11,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_16 (Dropout)                 │ (None, 1, 50)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 50)                  │          20,200 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_17 (Dropout)                 │ (None, 50)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_29 (Dense)                     │ (None, 1)                   │              51 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 32,051 (125.20 KB)
#  Trainable params: 32,051 (125.20 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
start = time.time()
history = model.fit(x_train, y_train, validation_data=(x_val, y_val),
                    epochs=100, batch_size=32, callbacks=[early_stopping, model_checkpoint],
                    verbose=1)
end = time.time()
print(f"Training time: {end - start} seconds")

# Save the model
model.save('best_model2.keras')
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 12s 1s/step - accuracy: 0.5367 - loss: 0.6915 - val_accuracy: 0.8125 - val_loss: 0.6880
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 0.7210 - loss: 0.6873 - val_accuracy: 0.8750 - val_loss: 0.6838
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.7532 - loss: 0.6843 - val_accuracy: 0.9375 - val_loss: 0.6797
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8709 - loss: 0.6759 - val_accuracy: 1.0000 - val_loss: 0.6755
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8714 - loss: 0.6745 - val_accuracy: 1.0000 - val_loss: 0.6712
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.8391 - loss: 0.6700 - val_accuracy: 1.0000 - val_loss: 0.6667
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8605 - loss: 0.6639 - val_accuracy: 1.0000 - val_loss: 0.6620
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9027 - loss: 0.6565 - val_accuracy: 0.9375 - val_loss: 0.6572
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8397 - loss: 0.6546 - val_accuracy: 0.9375 - val_loss: 0.6521
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9027 - loss: 0.6460 - val_accuracy: 0.9375 - val_loss: 0.6467
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9032 - loss: 0.6421 - val_accuracy: 0.9375 - val_loss: 0.6410
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.9032 - loss: 0.6300 - val_accuracy: 0.9375 - val_loss: 0.6350
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.9032 - loss: 0.6250 - val_accuracy: 0.9375 - val_loss: 0.6286
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step - accuracy: 0.8506 - loss: 0.6196 - val_accuracy: 0.9375 - val_loss: 0.6217
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step - accuracy: 0.8928 - loss: 0.6105 - val_accuracy: 0.9375 - val_loss: 0.6144
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - accuracy: 0.8709 - loss: 0.6006 - val_accuracy: 0.9375 - val_loss: 0.6067
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.9027 - loss: 0.5886 - val_accuracy: 0.9375 - val_loss: 0.5985
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 247ms/step - accuracy: 0.8714 - loss: 0.5848 - val_accuracy: 0.9375 - val_loss: 0.5900
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.9349 - loss: 0.5692 - val_accuracy: 0.9375 - val_loss: 0.5809
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - accuracy: 0.9032 - loss: 0.5615 - val_accuracy: 0.9375 - val_loss: 0.5715
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - accuracy: 0.9032 - loss: 0.5507 - val_accuracy: 0.9375 - val_loss: 0.5616
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8928 - loss: 0.5463 - val_accuracy: 0.9375 - val_loss: 0.5514
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step - accuracy: 0.8714 - loss: 0.5293 - val_accuracy: 0.9375 - val_loss: 0.5409
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.